# %% [markdown]
# # Import Tools

# %%
###Modules Utilized 
import sklearn
import nltk
import numpy as np
import pandas as pd
from pycaret.classification import *
from pycaret.datasets import get_data
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer, CountVectorizer

# %% [markdown]
# # Load Data

# %%
#data used to train the supervised models in milestone 2
data = pd.read_parquet('supervised_learning_data')

# %%
#data = data.sample(frac=0.5, replace=True, random_state=1)

#binary classification
data = data[data.sentiment != 1]

data = data.rename(columns={"pre_process": "review",
                             "sentiment": "Flag_1"})
data.head()
# Out:
#                                               review  Flag_1
# 0  engrossing page turner race class bullying gra...       2
# 1  interesting debut “ hello niveus high it ’ s t...       2
# 2             wow ordered book teenage daughter luvs       2
# 3  definitely ya novel great plot childish charac...       2
# 4  timely book engrossing story intrigued premise...       2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 337148 entries, 0 to 362923
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   review  337148 non-null  object
#  1   Flag_1  337148 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 7.7+ MB

# %% [markdown]
# # Vectorize Data
#
# Sklearn provides facilities to extract numerical features from a text document by tokenizing, counting and normalising. CountVectorizer performs the task of tokenizing and counting, while TfidfTransformer normalizes the data. TfidfVectorizer, on the other hand, performs all three operations, thereby streamlining the process of natural language processing.

# %% [markdown]
# ### Create Dataframe

# %%
#Set vectorizers
# %time v = TfidfVectorizer(max_features=800, ngram_range=(1, 4))
# %time V = v.fit_transform(data['review'])

df_tf = pd.DataFrame(V.toarray(), columns=v.vocabulary_)
#display(df_tf.head())
# Out:
# CPU times: user 11 µs, sys: 9 µs, total: 20 µs
# Wall time: 23.8 µs
# CPU times: user 3min, sys: 11.2 s, total: 3min 11s
# Wall time: 3min 12s

# %%
#Preparing processed and BoW-TF embedded data for Classification
df_tf_m = pd.concat([data, df_tf], axis = 1)
df_tf_m.drop(columns=['review'], inplace = True)
print(df_tf_m.shape)
#df_tf_m.head()
# Out:
# (361528, 800)

# %%
df_tf_m = df_tf_m.dropna()

# %% [markdown]
# # Supervised Learning Set-Up

# %% [markdown]
# ### Initiate Pipeline

# %%
#build models using data
# %time s = setup(df_tf_m, target = 'Flag_1', feature_selection = True, fix_imbalance=True,train_size = 0.80,session_id = 5)
# Out:
# <style type="text/css">
# #T_a4fd6_row9_col1, #T_a4fd6_row13_col1, #T_a4fd6_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a4fd6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4fd6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a4fd6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4fd6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4fd6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a4fd6_row0_col1" class="data row0 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4fd6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a4fd6_row1_col1" class="data row1 col1" >Flag_1</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4fd6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a4fd6_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4fd6_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_a4fd6_row3_col1" class="data row3 col1" >0.0: 0, 2.0: 1</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4fd6_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_a4fd6_row4_col1" class="data row4 col1" >(312768, 800)</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a4fd6_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_a4fd6_row5_col1" class="data row5 col1" >(514786, 160)</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a4fd6_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_a4fd6_row6_col1" class="data row6 col1" >(452232, 160)</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a4fd6_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_a4fd6_row7_col1" class="data row7 col1" >(62554, 160)</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a4fd6_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_a4fd6_row8_col1" class="data row8 col1" >799</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a4fd6_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_a4fd6_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a4fd6_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_a4fd6_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a4fd6_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_a4fd6_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a4fd6_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_a4fd6_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a4fd6_row13_col0" class="data row13 col0" >Fix imbalance</td>
#       <td id="T_a4fd6_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a4fd6_row14_col0" class="data row14 col0" >Fix imbalance method</td>
#       <td id="T_a4fd6_row14_col1" class="data row14 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a4fd6_row15_col0" class="data row15 col0" >Feature selection</td>
#       <td id="T_a4fd6_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a4fd6_row16_col0" class="data row16 col0" >Feature selection method</td>
#       <td id="T_a4fd6_row16_col1" class="data row16 col1" >classic</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a4fd6_row17_col0" class="data row17 col0" >Feature selection estimator</td>
#       <td id="T_a4fd6_row17_col1" class="data row17 col1" >lightgbm</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a4fd6_row18_col0" class="data row18 col0" >Number of features selected</td>
#       <td id="T_a4fd6_row18_col1" class="data row18 col1" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a4fd6_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_a4fd6_row19_col1" class="data row19 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a4fd6_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_a4fd6_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a4fd6_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_a4fd6_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a4fd6_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_a4fd6_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a4fd6_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_a4fd6_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a4fd6_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_a4fd6_row24_col1" class="data row24 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a4fd6_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a4fd6_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_a4fd6_row25_col1" class="data row25 col1" >a63d</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 16min 39s, sys: 48.4 s, total: 17min 28s
# Wall time: 1min 52s

# %%
# %time best_models = compare_models(n_select = 3)
save_model(best_models[0] , 'bestmodel1')
save_model(best_models[1] , 'bestmodel2')
save_model(best_models[2] , 'bestmodel3')
# Out:
# <style type="text/css">
# #T_8d46a th {
#   text-align: left;
# }
# #T_8d46a_row0_col0, #T_8d46a_row0_col2, #T_8d46a_row0_col4, #T_8d46a_row0_col6, #T_8d46a_row0_col7, #T_8d46a_row1_col0, #T_8d46a_row1_col1, #T_8d46a_row1_col2, #T_8d46a_row1_col3, #T_8d46a_row1_col4, #T_8d46a_row1_col5, #T_8d46a_row1_col6, #T_8d46a_row1_col7, #T_8d46a_row2_col0, #T_8d46a_row2_col1, #T_8d46a_row2_col2, #T_8d46a_row2_col3, #T_8d46a_row2_col4, #T_8d46a_row2_col5, #T_8d46a_row2_col6, #T_8d46a_row2_col7, #T_8d46a_row3_col0, #T_8d46a_row3_col1, #T_8d46a_row3_col2, #T_8d46a_row3_col3, #T_8d46a_row3_col4, #T_8d46a_row3_col5, #T_8d46a_row3_col6, #T_8d46a_row3_col7, #T_8d46a_row4_col0, #T_8d46a_row4_col1, #T_8d46a_row4_col2, #T_8d46a_row4_col3, #T_8d46a_row4_col4, #T_8d46a_row4_col5, #T_8d46a_row4_col6, #T_8d46a_row4_col7, #T_8d46a_row5_col0, #T_8d46a_row5_col1, #T_8d46a_row5_col2, #T_8d46a_row5_col3, #T_8d46a_row5_col4, #T_8d46a_row5_col5, #T_8d46a_row5_col6, #T_8d46a_row5_col7, #T_8d46a_row6_col0, #T_8d46a_row6_col1, #T_8d46a_row6_col2, #T_8d46a_row6_col3, #T_8d46a_row6_col4, #T_8d46a_row6_col5, #T_8d46a_row6_col6, #T_8d46a_row6_col7, #T_8d46a_row7_col0, #T_8d46a_row7_col1, #T_8d46a_row7_col2, #T_8d46a_row7_col3, #T_8d46a_row7_col4, #T_8d46a_row7_col5, #T_8d46a_row7_col6, #T_8d46a_row7_col7, #T_8d46a_row8_col0, #T_8d46a_row8_col1, #T_8d46a_row8_col3, #T_8d46a_row8_col4, #T_8d46a_row8_col5, #T_8d46a_row8_col6, #T_8d46a_row8_col7, #T_8d46a_row9_col0, #T_8d46a_row9_col1, #T_8d46a_row9_col2, #T_8d46a_row9_col3, #T_8d46a_row9_col4, #T_8d46a_row9_col5, #T_8d46a_row9_col6, #T_8d46a_row9_col7, #T_8d46a_row10_col0, #T_8d46a_row10_col1, #T_8d46a_row10_col2, #T_8d46a_row10_col3, #T_8d46a_row10_col4, #T_8d46a_row10_col5, #T_8d46a_row10_col6, #T_8d46a_row10_col7, #T_8d46a_row11_col0, #T_8d46a_row11_col1, #T_8d46a_row11_col2, #T_8d46a_row11_col3, #T_8d46a_row11_col5, #T_8d46a_row12_col0, #T_8d46a_row12_col1, #T_8d46a_row12_col2, #T_8d46a_row12_col3, #T_8d46a_row12_col4, #T_8d46a_row12_col5, #T_8d46a_row12_col6, #T_8d46a_row12_col7, #T_8d46a_row13_col0, #T_8d46a_row13_col1, #T_8d46a_row13_col2, #T_8d46a_row13_col3, #T_8d46a_row13_col4, #T_8d46a_row13_col5, #T_8d46a_row13_col6, #T_8d46a_row13_col7 {
#   text-align: left;
# }
# #T_8d46a_row0_col1, #T_8d46a_row0_col3, #T_8d46a_row0_col5, #T_8d46a_row8_col2, #T_8d46a_row11_col4, #T_8d46a_row11_col6, #T_8d46a_row11_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8d46a_row0_col8, #T_8d46a_row1_col8, #T_8d46a_row2_col8, #T_8d46a_row3_col8, #T_8d46a_row4_col8, #T_8d46a_row5_col8, #T_8d46a_row6_col8, #T_8d46a_row7_col8, #T_8d46a_row8_col8, #T_8d46a_row9_col8, #T_8d46a_row10_col8, #T_8d46a_row12_col8, #T_8d46a_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8d46a_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_8d46a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d46a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8d46a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8d46a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8d46a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8d46a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8d46a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8d46a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8d46a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_8d46a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d46a_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_8d46a_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_8d46a_row0_col1" class="data row0 col1" >0.8787</td>
#       <td id="T_8d46a_row0_col2" class="data row0 col2" >0.5039</td>
#       <td id="T_8d46a_row0_col3" class="data row0 col3" >0.9690</td>
#       <td id="T_8d46a_row0_col4" class="data row0 col4" >0.9038</td>
#       <td id="T_8d46a_row0_col5" class="data row0 col5" >0.9352</td>
#       <td id="T_8d46a_row0_col6" class="data row0 col6" >0.0010</td>
#       <td id="T_8d46a_row0_col7" class="data row0 col7" >0.0012</td>
#       <td id="T_8d46a_row0_col8" class="data row0 col8" >26.9280</td>
#     </tr>
#     <tr>
#       <th id="T_8d46a_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_8d46a_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_8d46a_row1_col1" class="data row1 col1" >0.8622</td>
#       <td id="T_8d46a_row1_col2" class="data row1 col2" >0.5003</td>
#       <td id="T_8d46a_row1_col3" class="data row1 col3" >0.9488</td>
#       <td id="T_8d46a_row1_col4" class="data row1 col4" >0.9036</td>
#       <td id="T_8d46a_row1_col5" class="data row1 col5" >0.9256</td>
#       <td id="T_8d46a_row1_col6" class="data row1 col6" >-0.0014</td>
#       <td id="T_8d46a_row1_col7" class="data row1 col7" >-0.0014</td>
#       <td id="T_8d46a_row1_col8" class="data row1 col8" >20.7090</td>
#     </tr>
#     <tr>
#       <th id="T_8d46a_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_8d46a_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8d46a_row2_col1" class="data row2 col1" >0.8185</td>
#       <td id="T_8d46a_row2_col2" class="data row2 col2" >0.5070</td>
#       <td id="T_8d46a_row2_col3" class="data row2 col3" >0.8945</td>
#       <td id="T_8d46a_row2_col4" class="data row2 col4" >0.9037</td>
#       <td id="T_8d46a_row2_col5" class="data row2 col5" >0.8991</td>
#       <td id="T_8d46a_row2_col6" class="data row2 col6" >0.0002</td>
#       <td id="T_8d46a_row2_col7" class="data row2 col7" >0.0002</td>
#       <td id="T_8d46a_row2_col8" class="data row2 col8" >18.8750</td>
#     </tr>
#     <tr>
#       <th id="T_8d46a_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_8d46a_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_8d46a_row3_col1" class="data row3 col1" >0.7382</td>
#       <td id="T_8d46a_row3_col2" class="data row3 col2" >0.4929</td>
#       <td id="T_8d46a_row3_col3" class="data row3 col3" >0.7961</td>
#       <td id="T_8d46a_row3_col4" class="data row3 col4" >0.9026</td>
#       <td id="T_8d46a_row3_col5" class="data row3 col5" >0.8460</td>
#       <td id="T_8d46a_row3_col6" class="data row3 col6" >-0.0064</td>
#       <td id="T_8d46a_row3_col7" class="data row3 col7" >-0.0071</td>
#       <td id="T_8d46a_row3_col8" class="data row3 col8" >48.7080</td>
#     </tr>
#     <tr>
#       <th id="T_8d46a_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_8d46a_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_8d46a_row4_col1" class="data row4 col1" >0.7319</td>
#       <td id="T_8d46a_row4_col2" class="data row4 col2" >0.5012</td>
#       <td id="T_8d46a_row4_col3" class="data row4 col3" >0.7866</td>
#       <td id="T_8d46a_row4_col4" class="data row4 col4" >0.9043</td>
#       <td id="T_8d46a_row4_col5" class="data row4 col5" >0.8413</td>
#       <td id="T_8d46a_row4_col6" class="data row4 col6" >0.0033</td>
#       <td id="T_8d46a_row4_col7" class="data row4 col7" >0.0037</td>
#       <td id="T_8d46a_row4_col8" class="data row4 col8" >18.8070</td>
#     </tr>
#     <tr>
#       <th id="T_8d46a_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_8d46a_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_8d46a_row5_col1" class="data row5 col1" >0.6698</td>
#       <td id="T_8d46a_row5_col2" class="data row5 col2" >0.4958</td>
#       <td id="T_8d46a_row5_col3" class="data row5 col3" >0.7110</td>
#       <td id="T_8d46a_row5_col4" class="data row5 col4" >0.9030</td>
#       <td id="T_8d46a_row5_col5" class="data row5 col5" >0.7956</td>
#       <td id="T_8d46a_row5_col6" class="data row5 col6" >-0.0030</td>
#       <td id="T_8d46a_row5_col7" class="data row5 col7" >-0.
# CPU times: user 36min 38s, sys: 2min 59s, total: 39min 38s
# Wall time: 54min 18s
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['page', 'race', 'class', 'ive',
#                                               'never', 'fan', 'girl', 'book',
#                                               'series', 'enjoyed', 'get', 'isnt',
#                                               'favorite', 'however',
#                                               'incredibly', 'awesom...
#                   LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                  colsample_bytree=1.0, importance_type='split',
#                                  learning_rate=0.1, max_depth=-1,
#                                  min_child_samples=20, min_child_weight=0.001,
#                                  min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                  num_leaves=31, objective=None, random_state=5,
#                                  reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                                  subsample=1.0, subsample_for_bin=200000,
#                                  subsample_freq=0))],
#           verbose=False),
#  'bestmodel3.pkl')

# %%
# %time ensemble_et = ensemble_model(best_models[0])
save_model(ensemble_et , 'ensemble_et')
# Out:
# <style type="text/css">
# #T_c3219_row10_col0, #T_c3219_row10_col1, #T_c3219_row10_col2, #T_c3219_row10_col3, #T_c3219_row10_col4, #T_c3219_row10_col5, #T_c3219_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c3219">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3219_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c3219_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c3219_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c3219_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c3219_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c3219_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c3219_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3219_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3219_row0_col0" class="data row0 col0" >0.8790</td>
#       <td id="T_c3219_row0_col1" class="data row0 col1" >0.5025</td>
#       <td id="T_c3219_row0_col2" class="data row0 col2" >0.9694</td>
#       <td id="T_c3219_row0_col3" class="data row0 col3" >0.9037</td>
#       <td id="T_c3219_row0_col4" class="data row0 col4" >0.9354</td>
#       <td id="T_c3219_row0_col5" class="data row0 col5" >0.0007</td>
#       <td id="T_c3219_row0_col6" class="data row0 col6" >0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3219_row1_col0" class="data row1 col0" >0.8792</td>
#       <td id="T_c3219_row1_col1" class="data row1 col1" >0.5036</td>
#       <td id="T_c3219_row1_col2" class="data row1 col2" >0.9689</td>
#       <td id="T_c3219_row1_col3" class="data row1 col3" >0.9043</td>
#       <td id="T_c3219_row1_col4" class="data row1 col4" >0.9355</td>
#       <td id="T_c3219_row1_col5" class="data row1 col5" >0.0100</td>
#       <td id="T_c3219_row1_col6" class="data row1 col6" >0.0118</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3219_row2_col0" class="data row2 col0" >0.8792</td>
#       <td id="T_c3219_row2_col1" class="data row2 col1" >0.5101</td>
#       <td id="T_c3219_row2_col2" class="data row2 col2" >0.9696</td>
#       <td id="T_c3219_row2_col3" class="data row2 col3" >0.9037</td>
#       <td id="T_c3219_row2_col4" class="data row2 col4" >0.9355</td>
#       <td id="T_c3219_row2_col5" class="data row2 col5" >0.0010</td>
#       <td id="T_c3219_row2_col6" class="data row2 col6" >0.0012</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3219_row3_col0" class="data row3 col0" >0.8807</td>
#       <td id="T_c3219_row3_col1" class="data row3 col1" >0.5050</td>
#       <td id="T_c3219_row3_col2" class="data row3 col2" >0.9707</td>
#       <td id="T_c3219_row3_col3" class="data row3 col3" >0.9043</td>
#       <td id="T_c3219_row3_col4" class="data row3 col4" >0.9363</td>
#       <td id="T_c3219_row3_col5" class="data row3 col5" >0.0104</td>
#       <td id="T_c3219_row3_col6" class="data row3 col6" >0.0124</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3219_row4_col0" class="data row4 col0" >0.8781</td>
#       <td id="T_c3219_row4_col1" class="data row4 col1" >0.5045</td>
#       <td id="T_c3219_row4_col2" class="data row4 col2" >0.9680</td>
#       <td id="T_c3219_row4_col3" class="data row4 col3" >0.9039</td>
#       <td id="T_c3219_row4_col4" class="data row4 col4" >0.9349</td>
#       <td id="T_c3219_row4_col5" class="data row4 col5" >0.0035</td>
#       <td id="T_c3219_row4_col6" class="data row4 col6" >0.0041</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3219_row5_col0" class="data row5 col0" >0.8787</td>
#       <td id="T_c3219_row5_col1" class="data row5 col1" >0.5025</td>
#       <td id="T_c3219_row5_col2" class="data row5 col2" >0.9695</td>
#       <td id="T_c3219_row5_col3" class="data row5 col3" >0.9033</td>
#       <td id="T_c3219_row5_col4" class="data row5 col4" >0.9352</td>
#       <td id="T_c3219_row5_col5" class="data row5 col5" >-0.0068</td>
#       <td id="T_c3219_row5_col6" class="data row5 col6" >-0.0082</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3219_row6_col0" class="data row6 col0" >0.8803</td>
#       <td id="T_c3219_row6_col1" class="data row6 col1" >0.5023</td>
#       <td id="T_c3219_row6_col2" class="data row6 col2" >0.9708</td>
#       <td id="T_c3219_row6_col3" class="data row6 col3" >0.9039</td>
#       <td id="T_c3219_row6_col4" class="data row6 col4" >0.9362</td>
#       <td id="T_c3219_row6_col5" class="data row6 col5" >0.0039</td>
#       <td id="T_c3219_row6_col6" class="data row6 col6" >0.0047</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3219_row7_col0" class="data row7 col0" >0.8789</td>
#       <td id="T_c3219_row7_col1" class="data row7 col1" >0.5078</td>
#       <td id="T_c3219_row7_col2" class="data row7 col2" >0.9694</td>
#       <td id="T_c3219_row7_col3" class="data row7 col3" >0.9036</td>
#       <td id="T_c3219_row7_col4" class="data row7 col4" >0.9354</td>
#       <td id="T_c3219_row7_col5" class="data row7 col5" >-0.0016</td>
#       <td id="T_c3219_row7_col6" class="data row7 col6" >-0.0019</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c3219_row8_col0" class="data row8 col0" >0.8786</td>
#       <td id="T_c3219_row8_col1" class="data row8 col1" >0.5135</td>
#       <td id="T_c3219_row8_col2" class="data row8 col2" >0.9690</td>
#       <td id="T_c3219_row8_col3" class="data row8 col3" >0.9037</td>
#       <td id="T_c3219_row8_col4" class="data row8 col4" >0.9352</td>
#       <td id="T_c3219_row8_col5" class="data row8 col5" >-0.0004</td>
#       <td id="T_c3219_row8_col6" class="data row8 col6" >-0.0005</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c3219_row9_col0" class="data row9 col0" >0.8792</td>
#       <td id="T_c3219_row9_col1" class="data row9 col1" >0.4959</td>
#       <td id="T_c3219_row9_col2" class="data row9 col2" >0.9701</td>
#       <td id="T_c3219_row9_col3" class="data row9 col3" >0.9033</td>
#       <td id="T_c3219_row9_col4" class="data row9 col4" >0.9355</td>
#       <td id="T_c3219_row9_col5" class="data row9 col5" >-0.0054</td>
#       <td id="T_c3219_row9_col6" class="data row9 col6" >-0.0065</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c3219_row10_col0" class="data row10 col0" >0.8792</td>
#       <td id="T_c3219_row10_col1" class="data row10 col1" >0.5048</td>
#       <td id="T_c3219_row10_col2" class="data row10 col2" >0.9695</td>
#       <td id="T_c3219_row10_col3" class="data row10 col3" >0.9038</td>
#       <td id="T_c3219_row10_col4" class="data row10 col4" >0.9355</td>
#       <td id="T_c3219_row10_col5" class="data row10 col5" >0.0015</td>
#       <td id="T_c3219_row10_col6" class="data row10 col6" >0.0018</td>
#     </tr>
#     <tr>
#       <th id="T_c3219_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c3219_row11_col0" class="data row11 col0" >0.0007</td>
#       <td id="T_c3219_row11_col1" class="data row11 col1" >0.0046</td>
#       <td id="T_c3219_row11_col2" class="data row11 col2" >0.0008</td>
#       <td id="T_c3219_row11_col3" class="data row11 col3" >0.0003</td>
#       <td id="T_c3219_ro
# CPU times: user 8min 18s, sys: 1min 8s, total: 9min 27s
# Wall time: 26min 14s
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['page', 'race', 'class', 'ive',
#                                               'never', 'fan', 'girl', 'book',
#                                               'series', 'enjoyed', 'get', 'isnt',
#                                               'favorite', 'however',
#                                               'incredibly', 'awesom...
#                                                                    max_leaf_nodes=None,
#                                                                    max_samples=None,
#                                                                    min_impurity_decrease=0.0,
#                                                                    min_samples_leaf=1,
#                                                                    min_samples_split=2,
#                                                                    min_weight_fraction_leaf=0.0,
#                                                                    n_estimators=100,
#                                                                    n_jobs=-1,
#                                                                    oob_score=False,
#                                                                    random_state=5,
#                                                                    verbose=0,
#                                                                    warm_start=False),
#                                     max_features=1.0, max_samples=1.0,
#                                     n_estimators=10, n_jobs=None,
#                                     oob_score=False, random_state=5, verbose=0,
#                                     warm_start=False))],
#           verbose=False),
#  'ensemble_et.pkl')

# %%
# %time ensemble_rf = ensemble_model(best_models[1])
save_model(ensemble_rf , 'ensemble_rf')
# Out:
# <style type="text/css">
# #T_b9f99_row10_col0, #T_b9f99_row10_col1, #T_b9f99_row10_col2, #T_b9f99_row10_col3, #T_b9f99_row10_col4, #T_b9f99_row10_col5, #T_b9f99_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b9f99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9f99_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b9f99_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b9f99_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b9f99_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b9f99_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b9f99_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b9f99_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9f99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9f99_row0_col0" class="data row0 col0" >0.8651</td>
#       <td id="T_b9f99_row0_col1" class="data row0 col1" >0.4943</td>
#       <td id="T_b9f99_row0_col2" class="data row0 col2" >0.9523</td>
#       <td id="T_b9f99_row0_col3" class="data row0 col3" >0.9036</td>
#       <td id="T_b9f99_row0_col4" class="data row0 col4" >0.9273</td>
#       <td id="T_b9f99_row0_col5" class="data row0 col5" >-0.0010</td>
#       <td id="T_b9f99_row0_col6" class="data row0 col6" >-0.0011</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9f99_row1_col0" class="data row1 col0" >0.8647</td>
#       <td id="T_b9f99_row1_col1" class="data row1 col1" >0.4911</td>
#       <td id="T_b9f99_row1_col2" class="data row1 col2" >0.9514</td>
#       <td id="T_b9f99_row1_col3" class="data row1 col3" >0.9039</td>
#       <td id="T_b9f99_row1_col4" class="data row1 col4" >0.9271</td>
#       <td id="T_b9f99_row1_col5" class="data row1 col5" >0.0032</td>
#       <td id="T_b9f99_row1_col6" class="data row1 col6" >0.0034</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9f99_row2_col0" class="data row2 col0" >0.8632</td>
#       <td id="T_b9f99_row2_col1" class="data row2 col1" >0.5009</td>
#       <td id="T_b9f99_row2_col2" class="data row2 col2" >0.9506</td>
#       <td id="T_b9f99_row2_col3" class="data row2 col3" >0.9031</td>
#       <td id="T_b9f99_row2_col4" class="data row2 col4" >0.9262</td>
#       <td id="T_b9f99_row2_col5" class="data row2 col5" >-0.0081</td>
#       <td id="T_b9f99_row2_col6" class="data row2 col6" >-0.0086</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9f99_row3_col0" class="data row3 col0" >0.8659</td>
#       <td id="T_b9f99_row3_col1" class="data row3 col1" >0.4960</td>
#       <td id="T_b9f99_row3_col2" class="data row3 col2" >0.9522</td>
#       <td id="T_b9f99_row3_col3" class="data row3 col3" >0.9044</td>
#       <td id="T_b9f99_row3_col4" class="data row3 col4" >0.9277</td>
#       <td id="T_b9f99_row3_col5" class="data row3 col5" >0.0106</td>
#       <td id="T_b9f99_row3_col6" class="data row3 col6" >0.0113</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9f99_row4_col0" class="data row4 col0" >0.8625</td>
#       <td id="T_b9f99_row4_col1" class="data row4 col1" >0.5008</td>
#       <td id="T_b9f99_row4_col2" class="data row4 col2" >0.9484</td>
#       <td id="T_b9f99_row4_col3" class="data row4 col3" >0.9041</td>
#       <td id="T_b9f99_row4_col4" class="data row4 col4" >0.9257</td>
#       <td id="T_b9f99_row4_col5" class="data row4 col5" >0.0056</td>
#       <td id="T_b9f99_row4_col6" class="data row4 col6" >0.0059</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9f99_row5_col0" class="data row5 col0" >0.8633</td>
#       <td id="T_b9f99_row5_col1" class="data row5 col1" >0.5000</td>
#       <td id="T_b9f99_row5_col2" class="data row5 col2" >0.9501</td>
#       <td id="T_b9f99_row5_col3" class="data row5 col3" >0.9036</td>
#       <td id="T_b9f99_row5_col4" class="data row5 col4" >0.9263</td>
#       <td id="T_b9f99_row5_col5" class="data row5 col5" >-0.0017</td>
#       <td id="T_b9f99_row5_col6" class="data row5 col6" >-0.0018</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b9f99_row6_col0" class="data row6 col0" >0.8634</td>
#       <td id="T_b9f99_row6_col1" class="data row6 col1" >0.4985</td>
#       <td id="T_b9f99_row6_col2" class="data row6 col2" >0.9498</td>
#       <td id="T_b9f99_row6_col3" class="data row6 col3" >0.9039</td>
#       <td id="T_b9f99_row6_col4" class="data row6 col4" >0.9263</td>
#       <td id="T_b9f99_row6_col5" class="data row6 col5" >0.0031</td>
#       <td id="T_b9f99_row6_col6" class="data row6 col6" >0.0033</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b9f99_row7_col0" class="data row7 col0" >0.8626</td>
#       <td id="T_b9f99_row7_col1" class="data row7 col1" >0.5097</td>
#       <td id="T_b9f99_row7_col2" class="data row7 col2" >0.9489</td>
#       <td id="T_b9f99_row7_col3" class="data row7 col3" >0.9039</td>
#       <td id="T_b9f99_row7_col4" class="data row7 col4" >0.9258</td>
#       <td id="T_b9f99_row7_col5" class="data row7 col5" >0.0025</td>
#       <td id="T_b9f99_row7_col6" class="data row7 col6" >0.0027</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b9f99_row8_col0" class="data row8 col0" >0.8626</td>
#       <td id="T_b9f99_row8_col1" class="data row8 col1" >0.5041</td>
#       <td id="T_b9f99_row8_col2" class="data row8 col2" >0.9492</td>
#       <td id="T_b9f99_row8_col3" class="data row8 col3" >0.9036</td>
#       <td id="T_b9f99_row8_col4" class="data row8 col4" >0.9259</td>
#       <td id="T_b9f99_row8_col5" class="data row8 col5" >-0.0007</td>
#       <td id="T_b9f99_row8_col6" class="data row8 col6" >-0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b9f99_row9_col0" class="data row9 col0" >0.8622</td>
#       <td id="T_b9f99_row9_col1" class="data row9 col1" >0.5020</td>
#       <td id="T_b9f99_row9_col2" class="data row9 col2" >0.9498</td>
#       <td id="T_b9f99_row9_col3" class="data row9 col3" >0.9028</td>
#       <td id="T_b9f99_row9_col4" class="data row9 col4" >0.9257</td>
#       <td id="T_b9f99_row9_col5" class="data row9 col5" >-0.0128</td>
#       <td id="T_b9f99_row9_col6" class="data row9 col6" >-0.0136</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b9f99_row10_col0" class="data row10 col0" >0.8635</td>
#       <td id="T_b9f99_row10_col1" class="data row10 col1" >0.4997</td>
#       <td id="T_b9f99_row10_col2" class="data row10 col2" >0.9503</td>
#       <td id="T_b9f99_row10_col3" class="data row10 col3" >0.9037</td>
#       <td id="T_b9f99_row10_col4" class="data row10 col4" >0.9264</td>
#       <td id="T_b9f99_row10_col5" class="data row10 col5" >0.0001</td>
#       <td id="T_b9f99_row10_col6" class="data row10 col6" >0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_b9f99_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b9f99_row11_col0" class="data row11 col0" >0.0012</td>
#       <td id="T_b9f99_row11_col1" class="data row11 col1" >0.0050</td>
#       <td id="T_b9f99_row11_col2" class="data row11 col2" >0.0013</td>
#       <td id="T_b9f99_row11_col3" class="data row11 col3" >0.0005</td>
#       <td id="T_b9f99_
# CPU times: user 7min 6s, sys: 52.9 s, total: 7min 59s
# Wall time: 15min 39s
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['page', 'race', 'class', 'ive',
#                                               'never', 'fan', 'girl', 'book',
#                                               'series', 'enjoyed', 'get', 'isnt',
#                                               'favorite', 'however',
#                                               'incredibly', 'awesom...
#                                                                      max_leaf_nodes=None,
#                                                                      max_samples=None,
#                                                                      min_impurity_decrease=0.0,
#                                                                      min_samples_leaf=1,
#                                                                      min_samples_split=2,
#                                                                      min_weight_fraction_leaf=0.0,
#                                                                      n_estimators=100,
#                                                                      n_jobs=-1,
#                                                                      oob_score=False,
#                                                                      random_state=5,
#                                                                      verbose=0,
#                                                                      warm_start=False),
#                                     max_features=1.0, max_samples=1.0,
#                                     n_estimators=10, n_jobs=None,
#                                     oob_score=False, random_state=5, verbose=0,
#                                     warm_start=False))],
#           verbose=False),
#  'ensemble_rf.pkl')

# %%
# %time ensemble_lgbm = ensemble_model(best_models[2])
save_model(ensemble_lgbm , 'ensemble_lgbm')
# Out:
# <style type="text/css">
# #T_a9ae0_row10_col0, #T_a9ae0_row10_col1, #T_a9ae0_row10_col2, #T_a9ae0_row10_col3, #T_a9ae0_row10_col4, #T_a9ae0_row10_col5, #T_a9ae0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a9ae0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9ae0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a9ae0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a9ae0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a9ae0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a9ae0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a9ae0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a9ae0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9ae0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9ae0_row0_col0" class="data row0 col0" >0.8203</td>
#       <td id="T_a9ae0_row0_col1" class="data row0 col1" >0.5097</td>
#       <td id="T_a9ae0_row0_col2" class="data row0 col2" >0.8978</td>
#       <td id="T_a9ae0_row0_col3" class="data row0 col3" >0.9028</td>
#       <td id="T_a9ae0_row0_col4" class="data row0 col4" >0.9003</td>
#       <td id="T_a9ae0_row0_col5" class="data row0 col5" >-0.0090</td>
#       <td id="T_a9ae0_row0_col6" class="data row0 col6" >-0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9ae0_row1_col0" class="data row1 col0" >0.8218</td>
#       <td id="T_a9ae0_row1_col1" class="data row1 col1" >0.5092</td>
#       <td id="T_a9ae0_row1_col2" class="data row1 col2" >0.8985</td>
#       <td id="T_a9ae0_row1_col3" class="data row1 col3" >0.9037</td>
#       <td id="T_a9ae0_row1_col4" class="data row1 col4" >0.9011</td>
#       <td id="T_a9ae0_row1_col5" class="data row1 col5" >0.0002</td>
#       <td id="T_a9ae0_row1_col6" class="data row1 col6" >0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9ae0_row2_col0" class="data row2 col0" >0.8182</td>
#       <td id="T_a9ae0_row2_col1" class="data row2 col1" >0.5047</td>
#       <td id="T_a9ae0_row2_col2" class="data row2 col2" >0.8936</td>
#       <td id="T_a9ae0_row2_col3" class="data row2 col3" >0.9041</td>
#       <td id="T_a9ae0_row2_col4" class="data row2 col4" >0.8988</td>
#       <td id="T_a9ae0_row2_col5" class="data row2 col5" >0.0038</td>
#       <td id="T_a9ae0_row2_col6" class="data row2 col6" >0.0038</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9ae0_row3_col0" class="data row3 col0" >0.8235</td>
#       <td id="T_a9ae0_row3_col1" class="data row3 col1" >0.5203</td>
#       <td id="T_a9ae0_row3_col2" class="data row3 col2" >0.8993</td>
#       <td id="T_a9ae0_row3_col3" class="data row3 col3" >0.9048</td>
#       <td id="T_a9ae0_row3_col4" class="data row3 col4" >0.9020</td>
#       <td id="T_a9ae0_row3_col5" class="data row3 col5" >0.0114</td>
#       <td id="T_a9ae0_row3_col6" class="data row3 col6" >0.0114</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a9ae0_row4_col0" class="data row4 col0" >0.8200</td>
#       <td id="T_a9ae0_row4_col1" class="data row4 col1" >0.5116</td>
#       <td id="T_a9ae0_row4_col2" class="data row4 col2" >0.8952</td>
#       <td id="T_a9ae0_row4_col3" class="data row4 col3" >0.9047</td>
#       <td id="T_a9ae0_row4_col4" class="data row4 col4" >0.8999</td>
#       <td id="T_a9ae0_row4_col5" class="data row4 col5" >0.0093</td>
#       <td id="T_a9ae0_row4_col6" class="data row4 col6" >0.0094</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a9ae0_row5_col0" class="data row5 col0" >0.8157</td>
#       <td id="T_a9ae0_row5_col1" class="data row5 col1" >0.4893</td>
#       <td id="T_a9ae0_row5_col2" class="data row5 col2" >0.8920</td>
#       <td id="T_a9ae0_row5_col3" class="data row5 col3" >0.9029</td>
#       <td id="T_a9ae0_row5_col4" class="data row5 col4" >0.8974</td>
#       <td id="T_a9ae0_row5_col5" class="data row5 col5" >-0.0076</td>
#       <td id="T_a9ae0_row5_col6" class="data row5 col6" >-0.0076</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a9ae0_row6_col0" class="data row6 col0" >0.8235</td>
#       <td id="T_a9ae0_row6_col1" class="data row6 col1" >0.5125</td>
#       <td id="T_a9ae0_row6_col2" class="data row6 col2" >0.8987</td>
#       <td id="T_a9ae0_row6_col3" class="data row6 col3" >0.9053</td>
#       <td id="T_a9ae0_row6_col4" class="data row6 col4" >0.9020</td>
#       <td id="T_a9ae0_row6_col5" class="data row6 col5" >0.0164</td>
#       <td id="T_a9ae0_row6_col6" class="data row6 col6" >0.0164</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a9ae0_row7_col0" class="data row7 col0" >0.8188</td>
#       <td id="T_a9ae0_row7_col1" class="data row7 col1" >0.5019</td>
#       <td id="T_a9ae0_row7_col2" class="data row7 col2" >0.8959</td>
#       <td id="T_a9ae0_row7_col3" class="data row7 col3" >0.9028</td>
#       <td id="T_a9ae0_row7_col4" class="data row7 col4" >0.8994</td>
#       <td id="T_a9ae0_row7_col5" class="data row7 col5" >-0.0088</td>
#       <td id="T_a9ae0_row7_col6" class="data row7 col6" >-0.0088</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a9ae0_row8_col0" class="data row8 col0" >0.8188</td>
#       <td id="T_a9ae0_row8_col1" class="data row8 col1" >0.5209</td>
#       <td id="T_a9ae0_row8_col2" class="data row8 col2" >0.8952</td>
#       <td id="T_a9ae0_row8_col3" class="data row8 col3" >0.9034</td>
#       <td id="T_a9ae0_row8_col4" class="data row8 col4" >0.8993</td>
#       <td id="T_a9ae0_row8_col5" class="data row8 col5" >-0.0026</td>
#       <td id="T_a9ae0_row8_col6" class="data row8 col6" >-0.0026</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a9ae0_row9_col0" class="data row9 col0" >0.8185</td>
#       <td id="T_a9ae0_row9_col1" class="data row9 col1" >0.4988</td>
#       <td id="T_a9ae0_row9_col2" class="data row9 col2" >0.8958</td>
#       <td id="T_a9ae0_row9_col3" class="data row9 col3" >0.9027</td>
#       <td id="T_a9ae0_row9_col4" class="data row9 col4" >0.8992</td>
#       <td id="T_a9ae0_row9_col5" class="data row9 col5" >-0.0101</td>
#       <td id="T_a9ae0_row9_col6" class="data row9 col6" >-0.0101</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a9ae0_row10_col0" class="data row10 col0" >0.8199</td>
#       <td id="T_a9ae0_row10_col1" class="data row10 col1" >0.5079</td>
#       <td id="T_a9ae0_row10_col2" class="data row10 col2" >0.8962</td>
#       <td id="T_a9ae0_row10_col3" class="data row10 col3" >0.9037</td>
#       <td id="T_a9ae0_row10_col4" class="data row10 col4" >0.8999</td>
#       <td id="T_a9ae0_row10_col5" class="data row10 col5" >0.0003</td>
#       <td id="T_a9ae0_row10_col6" class="data row10 col6" >0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_a9ae0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a9ae0_row11_col0" class="data row11 col0" >0.0023</td>
#       <td id="T_a9ae0_row11_col1" class="data row11 col1" >0.0092</td>
#       <td id="T_a9ae0_row11_col2" class="data row11 col2" >0.0022</td>
#       <td id="T_a9ae0_row11_col3" class="data row11 col3" >0.0009</td>
#       <td id="T_a9ae0_
# CPU times: user 24min 10s, sys: 25.1 s, total: 24min 35s
# Wall time: 6min 8s
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['page', 'race', 'class', 'ive',
#                                               'never', 'fan', 'girl', 'book',
#                                               'series', 'enjoyed', 'get', 'isnt',
#                                               'favorite', 'however',
#                                               'incredibly', 'awesom...
#                                                              min_child_samples=20,
#                                                              min_child_weight=0.001,
#                                                              min_split_gain=0.0,
#                                                              n_estimators=100,
#                                                              n_jobs=-1,
#                                                              num_leaves=31,
#                                                              objective=None,
#                                                              random_state=5,
#                                                              reg_alpha=0.0,
#                                                              reg_lambda=0.0,
#                                                              silent='warn',
#                                                              subsample=1.0,
#                                                              subsample_for_bin=200000,
#                                                              subsample_freq=0),
#                                     max_features=1.0, max_samples=1.0,
#                                     n_estimators=10, n_jobs=None,
#                                     oob_score=False, random_state=5, verbose=0,
#                                     warm_start=False))],
#           verbose=False),
#  'ensemble_lgbm.pkl')

# %%
# %time blender_weighted_med = blend_models(best_models, weights = [0.50,0.30,0.20])
save_model(blender_weighted_med , 'blender_weighted_med')
# Out:
# <style type="text/css">
# #T_a6a5a_row10_col0, #T_a6a5a_row10_col1, #T_a6a5a_row10_col2, #T_a6a5a_row10_col3, #T_a6a5a_row10_col4, #T_a6a5a_row10_col5, #T_a6a5a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a6a5a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6a5a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a6a5a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a6a5a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a6a5a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a6a5a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a6a5a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a6a5a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6a5a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6a5a_row0_col0" class="data row0 col0" >0.8769</td>
#       <td id="T_a6a5a_row0_col1" class="data row0 col1" >0.5003</td>
#       <td id="T_a6a5a_row0_col2" class="data row0 col2" >0.9665</td>
#       <td id="T_a6a5a_row0_col3" class="data row0 col3" >0.9039</td>
#       <td id="T_a6a5a_row0_col4" class="data row0 col4" >0.9342</td>
#       <td id="T_a6a5a_row0_col5" class="data row0 col5" >0.0036</td>
#       <td id="T_a6a5a_row0_col6" class="data row0 col6" >0.0042</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6a5a_row1_col0" class="data row1 col0" >0.8750</td>
#       <td id="T_a6a5a_row1_col1" class="data row1 col1" >0.5038</td>
#       <td id="T_a6a5a_row1_col2" class="data row1 col2" >0.9648</td>
#       <td id="T_a6a5a_row1_col3" class="data row1 col3" >0.9035</td>
#       <td id="T_a6a5a_row1_col4" class="data row1 col4" >0.9331</td>
#       <td id="T_a6a5a_row1_col5" class="data row1 col5" >-0.0034</td>
#       <td id="T_a6a5a_row1_col6" class="data row1 col6" >-0.0039</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6a5a_row2_col0" class="data row2 col0" >0.8748</td>
#       <td id="T_a6a5a_row2_col1" class="data row2 col1" >0.5084</td>
#       <td id="T_a6a5a_row2_col2" class="data row2 col2" >0.9642</td>
#       <td id="T_a6a5a_row2_col3" class="data row2 col3" >0.9037</td>
#       <td id="T_a6a5a_row2_col4" class="data row2 col4" >0.9330</td>
#       <td id="T_a6a5a_row2_col5" class="data row2 col5" >0.0004</td>
#       <td id="T_a6a5a_row2_col6" class="data row2 col6" >0.0005</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6a5a_row3_col0" class="data row3 col0" >0.8762</td>
#       <td id="T_a6a5a_row3_col1" class="data row3 col1" >0.5052</td>
#       <td id="T_a6a5a_row3_col2" class="data row3 col2" >0.9652</td>
#       <td id="T_a6a5a_row3_col3" class="data row3 col3" >0.9043</td>
#       <td id="T_a6a5a_row3_col4" class="data row3 col4" >0.9337</td>
#       <td id="T_a6a5a_row3_col5" class="data row3 col5" >0.0093</td>
#       <td id="T_a6a5a_row3_col6" class="data row3 col6" >0.0107</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6a5a_row4_col0" class="data row4 col0" >0.8735</td>
#       <td id="T_a6a5a_row4_col1" class="data row4 col1" >0.5027</td>
#       <td id="T_a6a5a_row4_col2" class="data row4 col2" >0.9626</td>
#       <td id="T_a6a5a_row4_col3" class="data row4 col3" >0.9037</td>
#       <td id="T_a6a5a_row4_col4" class="data row4 col4" >0.9322</td>
#       <td id="T_a6a5a_row4_col5" class="data row4 col5" >-0.0006</td>
#       <td id="T_a6a5a_row4_col6" class="data row4 col6" >-0.0007</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6a5a_row5_col0" class="data row5 col0" >0.8737</td>
#       <td id="T_a6a5a_row5_col1" class="data row5 col1" >0.4994</td>
#       <td id="T_a6a5a_row5_col2" class="data row5 col2" >0.9636</td>
#       <td id="T_a6a5a_row5_col3" class="data row5 col3" >0.9031</td>
#       <td id="T_a6a5a_row5_col4" class="data row5 col4" >0.9324</td>
#       <td id="T_a6a5a_row5_col5" class="data row5 col5" >-0.0102</td>
#       <td id="T_a6a5a_row5_col6" class="data row5 col6" >-0.0116</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6a5a_row6_col0" class="data row6 col0" >0.8763</td>
#       <td id="T_a6a5a_row6_col1" class="data row6 col1" >0.5081</td>
#       <td id="T_a6a5a_row6_col2" class="data row6 col2" >0.9654</td>
#       <td id="T_a6a5a_row6_col3" class="data row6 col3" >0.9042</td>
#       <td id="T_a6a5a_row6_col4" class="data row6 col4" >0.9338</td>
#       <td id="T_a6a5a_row6_col5" class="data row6 col5" >0.0073</td>
#       <td id="T_a6a5a_row6_col6" class="data row6 col6" >0.0084</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6a5a_row7_col0" class="data row7 col0" >0.8748</td>
#       <td id="T_a6a5a_row7_col1" class="data row7 col1" >0.5095</td>
#       <td id="T_a6a5a_row7_col2" class="data row7 col2" >0.9644</td>
#       <td id="T_a6a5a_row7_col3" class="data row7 col3" >0.9035</td>
#       <td id="T_a6a5a_row7_col4" class="data row7 col4" >0.9330</td>
#       <td id="T_a6a5a_row7_col5" class="data row7 col5" >-0.0027</td>
#       <td id="T_a6a5a_row7_col6" class="data row7 col6" >-0.0031</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6a5a_row8_col0" class="data row8 col0" >0.8743</td>
#       <td id="T_a6a5a_row8_col1" class="data row8 col1" >0.5108</td>
#       <td id="T_a6a5a_row8_col2" class="data row8 col2" >0.9636</td>
#       <td id="T_a6a5a_row8_col3" class="data row8 col3" >0.9037</td>
#       <td id="T_a6a5a_row8_col4" class="data row8 col4" >0.9327</td>
#       <td id="T_a6a5a_row8_col5" class="data row8 col5" >0.0002</td>
#       <td id="T_a6a5a_row8_col6" class="data row8 col6" >0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6a5a_row9_col0" class="data row9 col0" >0.8749</td>
#       <td id="T_a6a5a_row9_col1" class="data row9 col1" >0.5004</td>
#       <td id="T_a6a5a_row9_col2" class="data row9 col2" >0.9649</td>
#       <td id="T_a6a5a_row9_col3" class="data row9 col3" >0.9032</td>
#       <td id="T_a6a5a_row9_col4" class="data row9 col4" >0.9330</td>
#       <td id="T_a6a5a_row9_col5" class="data row9 col5" >-0.0068</td>
#       <td id="T_a6a5a_row9_col6" class="data row9 col6" >-0.0078</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a6a5a_row10_col0" class="data row10 col0" >0.8750</td>
#       <td id="T_a6a5a_row10_col1" class="data row10 col1" >0.5049</td>
#       <td id="T_a6a5a_row10_col2" class="data row10 col2" >0.9645</td>
#       <td id="T_a6a5a_row10_col3" class="data row10 col3" >0.9037</td>
#       <td id="T_a6a5a_row10_col4" class="data row10 col4" >0.9331</td>
#       <td id="T_a6a5a_row10_col5" class="data row10 col5" >-0.0003</td>
#       <td id="T_a6a5a_row10_col6" class="data row10 col6" >-0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_a6a5a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a6a5a_row11_col0" class="data row11 col0" >0.0011</td>
#       <td id="T_a6a5a_row11_col1" class="data row11 col1" >0.0040</td>
#       <td id="T_a6a5a_row11_col2" class="data row11 col2" >0.0010</td>
#       <td id="T_a6a5a_row11_col3" class="data row11 col3" >0.0004</td>
#       <td id="T_a6a5
# CPU times: user 8min 16s, sys: 1min, total: 9min 17s
# Wall time: 11min 13s
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['page', 'race', 'class', 'ive',
#                                               'never', 'fan', 'girl', 'book',
#                                               'series', 'enjoyed', 'get', 'isnt',
#                                               'favorite', 'however',
#                                               'incredibly', 'awesom...
#                                                                learning_rate=0.1,
#                                                                max_depth=-1,
#                                                                min_child_samples=20,
#                                                                min_child_weight=0.001,
#                                                                min_split_gain=0.0,
#                                                                n_estimators=100,
#                                                                n_jobs=-1,
#                                                                num_leaves=31,
#                                                                objective=None,
#                                                                random_state=5,
#                                                                reg_alpha=0.0,
#                                                                reg_lambda=0.0,
#                                                                silent='warn',
#                                                                subsample=1.0,
#                                                                subsample_for_bin=200000,
#                                                                subsample_freq=0))],
#                                    flatten_transform=True, n_jobs=-1,
#                                    verbose=False, voting='soft',
#                                    weights=[0.5, 0.3, 0.2]))],
#           verbose=False),
#  'blender_weighted_med.pkl')

# %%
# %time blender_weighted_soft = blend_models(best_models, weights = [0.50,0.30,0.20], method='soft')
save_model(blender_weighted_soft , 'blender_weighted_soft')
# Out:
# <style type="text/css">
# #T_0a51a_row10_col0, #T_0a51a_row10_col1, #T_0a51a_row10_col2, #T_0a51a_row10_col3, #T_0a51a_row10_col4, #T_0a51a_row10_col5, #T_0a51a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0a51a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a51a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0a51a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0a51a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0a51a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0a51a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0a51a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0a51a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a51a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a51a_row0_col0" class="data row0 col0" >0.8777</td>
#       <td id="T_0a51a_row0_col1" class="data row0 col1" >0.5018</td>
#       <td id="T_0a51a_row0_col2" class="data row0 col2" >0.9672</td>
#       <td id="T_0a51a_row0_col3" class="data row0 col3" >0.9042</td>
#       <td id="T_0a51a_row0_col4" class="data row0 col4" >0.9346</td>
#       <td id="T_0a51a_row0_col5" class="data row0 col5" >0.0076</td>
#       <td id="T_0a51a_row0_col6" class="data row0 col6" >0.0088</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a51a_row1_col0" class="data row1 col0" >0.8758</td>
#       <td id="T_0a51a_row1_col1" class="data row1 col1" >0.4983</td>
#       <td id="T_0a51a_row1_col2" class="data row1 col2" >0.9653</td>
#       <td id="T_0a51a_row1_col3" class="data row1 col3" >0.9038</td>
#       <td id="T_0a51a_row1_col4" class="data row1 col4" >0.9335</td>
#       <td id="T_0a51a_row1_col5" class="data row1 col5" >0.0019</td>
#       <td id="T_0a51a_row1_col6" class="data row1 col6" >0.0022</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a51a_row2_col0" class="data row2 col0" >0.8740</td>
#       <td id="T_0a51a_row2_col1" class="data row2 col1" >0.5034</td>
#       <td id="T_0a51a_row2_col2" class="data row2 col2" >0.9637</td>
#       <td id="T_0a51a_row2_col3" class="data row2 col3" >0.9034</td>
#       <td id="T_0a51a_row2_col4" class="data row2 col4" >0.9326</td>
#       <td id="T_0a51a_row2_col5" class="data row2 col5" >-0.0049</td>
#       <td id="T_0a51a_row2_col6" class="data row2 col6" >-0.0056</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0a51a_row3_col0" class="data row3 col0" >0.8751</td>
#       <td id="T_0a51a_row3_col1" class="data row3 col1" >0.5043</td>
#       <td id="T_0a51a_row3_col2" class="data row3 col2" >0.9636</td>
#       <td id="T_0a51a_row3_col3" class="data row3 col3" >0.9044</td>
#       <td id="T_0a51a_row3_col4" class="data row3 col4" >0.9331</td>
#       <td id="T_0a51a_row3_col5" class="data row3 col5" >0.0110</td>
#       <td id="T_0a51a_row3_col6" class="data row3 col6" >0.0125</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0a51a_row4_col0" class="data row4 col0" >0.8749</td>
#       <td id="T_0a51a_row4_col1" class="data row4 col1" >0.5069</td>
#       <td id="T_0a51a_row4_col2" class="data row4 col2" >0.9632</td>
#       <td id="T_0a51a_row4_col3" class="data row4 col3" >0.9046</td>
#       <td id="T_0a51a_row4_col4" class="data row4 col4" >0.9330</td>
#       <td id="T_0a51a_row4_col5" class="data row4 col5" >0.0138</td>
#       <td id="T_0a51a_row4_col6" class="data row4 col6" >0.0156</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0a51a_row5_col0" class="data row5 col0" >0.8736</td>
#       <td id="T_0a51a_row5_col1" class="data row5 col1" >0.4934</td>
#       <td id="T_0a51a_row5_col2" class="data row5 col2" >0.9633</td>
#       <td id="T_0a51a_row5_col3" class="data row5 col3" >0.9033</td>
#       <td id="T_0a51a_row5_col4" class="data row5 col4" >0.9323</td>
#       <td id="T_0a51a_row5_col5" class="data row5 col5" >-0.0066</td>
#       <td id="T_0a51a_row5_col6" class="data row5 col6" >-0.0075</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0a51a_row6_col0" class="data row6 col0" >0.8764</td>
#       <td id="T_0a51a_row6_col1" class="data row6 col1" >0.5081</td>
#       <td id="T_0a51a_row6_col2" class="data row6 col2" >0.9659</td>
#       <td id="T_0a51a_row6_col3" class="data row6 col3" >0.9039</td>
#       <td id="T_0a51a_row6_col4" class="data row6 col4" >0.9339</td>
#       <td id="T_0a51a_row6_col5" class="data row6 col5" >0.0034</td>
#       <td id="T_0a51a_row6_col6" class="data row6 col6" >0.0039</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0a51a_row7_col0" class="data row7 col0" >0.8734</td>
#       <td id="T_0a51a_row7_col1" class="data row7 col1" >0.5138</td>
#       <td id="T_0a51a_row7_col2" class="data row7 col2" >0.9627</td>
#       <td id="T_0a51a_row7_col3" class="data row7 col3" >0.9035</td>
#       <td id="T_0a51a_row7_col4" class="data row7 col4" >0.9322</td>
#       <td id="T_0a51a_row7_col5" class="data row7 col5" >-0.0022</td>
#       <td id="T_0a51a_row7_col6" class="data row7 col6" >-0.0025</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0a51a_row8_col0" class="data row8 col0" >0.8741</td>
#       <td id="T_0a51a_row8_col1" class="data row8 col1" >0.5133</td>
#       <td id="T_0a51a_row8_col2" class="data row8 col2" >0.9636</td>
#       <td id="T_0a51a_row8_col3" class="data row8 col3" >0.9035</td>
#       <td id="T_0a51a_row8_col4" class="data row8 col4" >0.9326</td>
#       <td id="T_0a51a_row8_col5" class="data row8 col5" >-0.0032</td>
#       <td id="T_0a51a_row8_col6" class="data row8 col6" >-0.0037</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0a51a_row9_col0" class="data row9 col0" >0.8748</td>
#       <td id="T_0a51a_row9_col1" class="data row9 col1" >0.5014</td>
#       <td id="T_0a51a_row9_col2" class="data row9 col2" >0.9649</td>
#       <td id="T_0a51a_row9_col3" class="data row9 col3" >0.9032</td>
#       <td id="T_0a51a_row9_col4" class="data row9 col4" >0.9330</td>
#       <td id="T_0a51a_row9_col5" class="data row9 col5" >-0.0079</td>
#       <td id="T_0a51a_row9_col6" class="data row9 col6" >-0.0091</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0a51a_row10_col0" class="data row10 col0" >0.8750</td>
#       <td id="T_0a51a_row10_col1" class="data row10 col1" >0.5045</td>
#       <td id="T_0a51a_row10_col2" class="data row10 col2" >0.9643</td>
#       <td id="T_0a51a_row10_col3" class="data row10 col3" >0.9038</td>
#       <td id="T_0a51a_row10_col4" class="data row10 col4" >0.9331</td>
#       <td id="T_0a51a_row10_col5" class="data row10 col5" >0.0013</td>
#       <td id="T_0a51a_row10_col6" class="data row10 col6" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_0a51a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0a51a_row11_col0" class="data row11 col0" >0.0013</td>
#       <td id="T_0a51a_row11_col1" class="data row11 col1" >0.0060</td>
#       <td id="T_0a51a_row11_col2" class="data row11 col2" >0.0014</td>
#       <td id="T_0a51a_row11_col3" class="data row11 col3" >0.0005</td>
#       <td id="T_0a51a_
# CPU times: user 6min 19s, sys: 59 s, total: 7min 18s
# Wall time: 10min 59s
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['page', 'race', 'class', 'ive',
#                                               'never', 'fan', 'girl', 'book',
#                                               'series', 'enjoyed', 'get', 'isnt',
#                                               'favorite', 'however',
#                                               'incredibly', 'awesom...
#                                                                learning_rate=0.1,
#                                                                max_depth=-1,
#                                                                min_child_samples=20,
#                                                                min_child_weight=0.001,
#                                                                min_split_gain=0.0,
#                                                                n_estimators=100,
#                                                                n_jobs=-1,
#                                                                num_leaves=31,
#                                                                objective=None,
#                                                                random_state=5,
#                                                                reg_alpha=0.0,
#                                                                reg_lambda=0.0,
#                                                                silent='warn',
#                                                                subsample=1.0,
#                                                                subsample_for_bin=200000,
#                                                                subsample_freq=0))],
#                                    flatten_transform=True, n_jobs=-1,
#                                    verbose=False, voting='soft',
#                                    weights=[0.5, 0.3, 0.2]))],
#           verbose=False),
#  'blender_weighted_soft.pkl')

# %%
# %time stacker = stack_models(best_models)
save_model(stacker , 'stacker')
# Out:
# <style type="text/css">
# #T_adb02_row10_col0, #T_adb02_row10_col1, #T_adb02_row10_col2, #T_adb02_row10_col3, #T_adb02_row10_col4, #T_adb02_row10_col5, #T_adb02_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_adb02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adb02_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_adb02_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_adb02_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_adb02_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_adb02_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_adb02_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_adb02_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adb02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_adb02_row0_col0" class="data row0 col0" >0.8833</td>
#       <td id="T_adb02_row0_col1" class="data row0 col1" >0.5121</td>
#       <td id="T_adb02_row0_col2" class="data row0 col2" >0.9736</td>
#       <td id="T_adb02_row0_col3" class="data row0 col3" >0.9045</td>
#       <td id="T_adb02_row0_col4" class="data row0 col4" >0.9378</td>
#       <td id="T_adb02_row0_col5" class="data row0 col5" >0.0131</td>
#       <td id="T_adb02_row0_col6" class="data row0 col6" >0.0162</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_adb02_row1_col0" class="data row1 col0" >0.8814</td>
#       <td id="T_adb02_row1_col1" class="data row1 col1" >0.5084</td>
#       <td id="T_adb02_row1_col2" class="data row1 col2" >0.9721</td>
#       <td id="T_adb02_row1_col3" class="data row1 col3" >0.9039</td>
#       <td id="T_adb02_row1_col4" class="data row1 col4" >0.9368</td>
#       <td id="T_adb02_row1_col5" class="data row1 col5" >0.0036</td>
#       <td id="T_adb02_row1_col6" class="data row1 col6" >0.0043</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_adb02_row2_col0" class="data row2 col0" >0.8803</td>
#       <td id="T_adb02_row2_col1" class="data row2 col1" >0.5148</td>
#       <td id="T_adb02_row2_col2" class="data row2 col2" >0.9713</td>
#       <td id="T_adb02_row2_col3" class="data row2 col3" >0.9035</td>
#       <td id="T_adb02_row2_col4" class="data row2 col4" >0.9361</td>
#       <td id="T_adb02_row2_col5" class="data row2 col5" >-0.0032</td>
#       <td id="T_adb02_row2_col6" class="data row2 col6" >-0.0039</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_adb02_row3_col0" class="data row3 col0" >0.8818</td>
#       <td id="T_adb02_row3_col1" class="data row3 col1" >0.5059</td>
#       <td id="T_adb02_row3_col2" class="data row3 col2" >0.9728</td>
#       <td id="T_adb02_row3_col3" class="data row3 col3" >0.9038</td>
#       <td id="T_adb02_row3_col4" class="data row3 col4" >0.9370</td>
#       <td id="T_adb02_row3_col5" class="data row3 col5" >0.0014</td>
#       <td id="T_adb02_row3_col6" class="data row3 col6" >0.0018</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_adb02_row4_col0" class="data row4 col0" >0.8828</td>
#       <td id="T_adb02_row4_col1" class="data row4 col1" >0.5101</td>
#       <td id="T_adb02_row4_col2" class="data row4 col2" >0.9736</td>
#       <td id="T_adb02_row4_col3" class="data row4 col3" >0.9041</td>
#       <td id="T_adb02_row4_col4" class="data row4 col4" >0.9375</td>
#       <td id="T_adb02_row4_col5" class="data row4 col5" >0.0063</td>
#       <td id="T_adb02_row4_col6" class="data row4 col6" >0.0078</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_adb02_row5_col0" class="data row5 col0" >0.8783</td>
#       <td id="T_adb02_row5_col1" class="data row5 col1" >0.4955</td>
#       <td id="T_adb02_row5_col2" class="data row5 col2" >0.9690</td>
#       <td id="T_adb02_row5_col3" class="data row5 col3" >0.9034</td>
#       <td id="T_adb02_row5_col4" class="data row5 col4" >0.9350</td>
#       <td id="T_adb02_row5_col5" class="data row5 col5" >-0.0052</td>
#       <td id="T_adb02_row5_col6" class="data row5 col6" >-0.0062</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_adb02_row6_col0" class="data row6 col0" >0.8809</td>
#       <td id="T_adb02_row6_col1" class="data row6 col1" >0.5047</td>
#       <td id="T_adb02_row6_col2" class="data row6 col2" >0.9717</td>
#       <td id="T_adb02_row6_col3" class="data row6 col3" >0.9038</td>
#       <td id="T_adb02_row6_col4" class="data row6 col4" >0.9365</td>
#       <td id="T_adb02_row6_col5" class="data row6 col5" >0.0016</td>
#       <td id="T_adb02_row6_col6" class="data row6 col6" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_adb02_row7_col0" class="data row7 col0" >0.8804</td>
#       <td id="T_adb02_row7_col1" class="data row7 col1" >0.5177</td>
#       <td id="T_adb02_row7_col2" class="data row7 col2" >0.9708</td>
#       <td id="T_adb02_row7_col3" class="data row7 col3" >0.9040</td>
#       <td id="T_adb02_row7_col4" class="data row7 col4" >0.9362</td>
#       <td id="T_adb02_row7_col5" class="data row7 col5" >0.0046</td>
#       <td id="T_adb02_row7_col6" class="data row7 col6" >0.0055</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_adb02_row8_col0" class="data row8 col0" >0.8775</td>
#       <td id="T_adb02_row8_col1" class="data row8 col1" >0.5113</td>
#       <td id="T_adb02_row8_col2" class="data row8 col2" >0.9681</td>
#       <td id="T_adb02_row8_col3" class="data row8 col3" >0.9033</td>
#       <td id="T_adb02_row8_col4" class="data row8 col4" >0.9346</td>
#       <td id="T_adb02_row8_col5" class="data row8 col5" >-0.0059</td>
#       <td id="T_adb02_row8_col6" class="data row8 col6" >-0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_adb02_row9_col0" class="data row9 col0" >0.8816</td>
#       <td id="T_adb02_row9_col1" class="data row9 col1" >0.5094</td>
#       <td id="T_adb02_row9_col2" class="data row9 col2" >0.9732</td>
#       <td id="T_adb02_row9_col3" class="data row9 col3" >0.9033</td>
#       <td id="T_adb02_row9_col4" class="data row9 col4" >0.9369</td>
#       <td id="T_adb02_row9_col5" class="data row9 col5" >-0.0066</td>
#       <td id="T_adb02_row9_col6" class="data row9 col6" >-0.0082</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_adb02_row10_col0" class="data row10 col0" >0.8808</td>
#       <td id="T_adb02_row10_col1" class="data row10 col1" >0.5090</td>
#       <td id="T_adb02_row10_col2" class="data row10 col2" >0.9716</td>
#       <td id="T_adb02_row10_col3" class="data row10 col3" >0.9037</td>
#       <td id="T_adb02_row10_col4" class="data row10 col4" >0.9364</td>
#       <td id="T_adb02_row10_col5" class="data row10 col5" >0.0010</td>
#       <td id="T_adb02_row10_col6" class="data row10 col6" >0.0012</td>
#     </tr>
#     <tr>
#       <th id="T_adb02_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_adb02_row11_col0" class="data row11 col0" >0.0017</td>
#       <td id="T_adb02_row11_col1" class="data row11 col1" >0.0058</td>
#       <td id="T_adb02_row11_col2" class="data row11 col2" >0.0018</td>
#       <td id="T_adb02_row11_col3" class="data row11 col3" >0.0004</td>
#       <td id="T_adb02_ro
# CPU times: user 10min 52s, sys: 2min 24s, total: 13min 16s
# Wall time: 43min 59s
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['page', 'race', 'class', 'ive',
#                                               'never', 'fan', 'girl', 'book',
#                                               'series', 'enjoyed', 'get', 'isnt',
#                                               'favorite', 'however',
#                                               'incredibly', 'awesom...
#                                                                  subsample_for_bin=200000,
#                                                                  subsample_freq=0))],
#                                      final_estimator=LogisticRegression(C=1.0,
#                                                                         class_weight=None,
#                                                                         dual=False,
#                                                                         fit_intercept=True,
#                                                                         intercept_scaling=1,
#                                                                         l1_ratio=None,
#                                                                         max_iter=1000,
#                                                                         multi_class='auto',
#                                                                         n_jobs=None,
#                                                                         penalty='l2',
#                                                                         random_state=5,
#                                                                         solver='lbfgs',
#                                                                         tol=0.0001,
#                                                                         verbose=0,
#                                                                         warm_start=False),
#                                      n_jobs=-1, passthrough=True,
#                                      stack_method='auto', verbose=0))],
#           verbose=False),
#  'stacker.pkl')

# %%
# %time stacker_et = stack_models(best_models, meta_model = best_models[0])
save_model(stacker , 'stacker_et')
# Out:
# <style type="text/css">
# #T_78990_row10_col0, #T_78990_row10_col1, #T_78990_row10_col2, #T_78990_row10_col3, #T_78990_row10_col4, #T_78990_row10_col5, #T_78990_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_78990">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78990_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_78990_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_78990_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_78990_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_78990_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_78990_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_78990_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78990_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78990_row0_col0" class="data row0 col0" >0.8854</td>
#       <td id="T_78990_row0_col1" class="data row0 col1" >0.4994</td>
#       <td id="T_78990_row0_col2" class="data row0 col2" >0.9768</td>
#       <td id="T_78990_row0_col3" class="data row0 col3" >0.9041</td>
#       <td id="T_78990_row0_col4" class="data row0 col4" >0.9390</td>
#       <td id="T_78990_row0_col5" class="data row0 col5" >0.0064</td>
#       <td id="T_78990_row0_col6" class="data row0 col6" >0.0082</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78990_row1_col0" class="data row1 col0" >0.8843</td>
#       <td id="T_78990_row1_col1" class="data row1 col1" >0.4950</td>
#       <td id="T_78990_row1_col2" class="data row1 col2" >0.9763</td>
#       <td id="T_78990_row1_col3" class="data row1 col3" >0.9035</td>
#       <td id="T_78990_row1_col4" class="data row1 col4" >0.9385</td>
#       <td id="T_78990_row1_col5" class="data row1 col5" >-0.0032</td>
#       <td id="T_78990_row1_col6" class="data row1 col6" >-0.0041</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78990_row2_col0" class="data row2 col0" >0.8845</td>
#       <td id="T_78990_row2_col1" class="data row2 col1" >0.4938</td>
#       <td id="T_78990_row2_col2" class="data row2 col2" >0.9763</td>
#       <td id="T_78990_row2_col3" class="data row2 col3" >0.9036</td>
#       <td id="T_78990_row2_col4" class="data row2 col4" >0.9385</td>
#       <td id="T_78990_row2_col5" class="data row2 col5" >-0.0019</td>
#       <td id="T_78990_row2_col6" class="data row2 col6" >-0.0024</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78990_row3_col0" class="data row3 col0" >0.8859</td>
#       <td id="T_78990_row3_col1" class="data row3 col1" >0.5049</td>
#       <td id="T_78990_row3_col2" class="data row3 col2" >0.9775</td>
#       <td id="T_78990_row3_col3" class="data row3 col3" >0.9040</td>
#       <td id="T_78990_row3_col4" class="data row3 col4" >0.9393</td>
#       <td id="T_78990_row3_col5" class="data row3 col5" >0.0061</td>
#       <td id="T_78990_row3_col6" class="data row3 col6" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78990_row4_col0" class="data row4 col0" >0.8830</td>
#       <td id="T_78990_row4_col1" class="data row4 col1" >0.5041</td>
#       <td id="T_78990_row4_col2" class="data row4 col2" >0.9743</td>
#       <td id="T_78990_row4_col3" class="data row4 col3" >0.9038</td>
#       <td id="T_78990_row4_col4" class="data row4 col4" >0.9377</td>
#       <td id="T_78990_row4_col5" class="data row4 col5" >0.0007</td>
#       <td id="T_78990_row4_col6" class="data row4 col6" >0.0009</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_78990_row5_col0" class="data row5 col0" >0.8839</td>
#       <td id="T_78990_row5_col1" class="data row5 col1" >0.4834</td>
#       <td id="T_78990_row5_col2" class="data row5 col2" >0.9759</td>
#       <td id="T_78990_row5_col3" class="data row5 col3" >0.9033</td>
#       <td id="T_78990_row5_col4" class="data row5 col4" >0.9382</td>
#       <td id="T_78990_row5_col5" class="data row5 col5" >-0.0069</td>
#       <td id="T_78990_row5_col6" class="data row5 col6" >-0.0088</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_78990_row6_col0" class="data row6 col0" >0.8852</td>
#       <td id="T_78990_row6_col1" class="data row6 col1" >0.4932</td>
#       <td id="T_78990_row6_col2" class="data row6 col2" >0.9767</td>
#       <td id="T_78990_row6_col3" class="data row6 col3" >0.9039</td>
#       <td id="T_78990_row6_col4" class="data row6 col4" >0.9389</td>
#       <td id="T_78990_row6_col5" class="data row6 col5" >0.0043</td>
#       <td id="T_78990_row6_col6" class="data row6 col6" >0.0056</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_78990_row7_col0" class="data row7 col0" >0.8847</td>
#       <td id="T_78990_row7_col1" class="data row7 col1" >0.5005</td>
#       <td id="T_78990_row7_col2" class="data row7 col2" >0.9765</td>
#       <td id="T_78990_row7_col3" class="data row7 col3" >0.9037</td>
#       <td id="T_78990_row7_col4" class="data row7 col4" >0.9387</td>
#       <td id="T_78990_row7_col5" class="data row7 col5" >-0.0004</td>
#       <td id="T_78990_row7_col6" class="data row7 col6" >-0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_78990_row8_col0" class="data row8 col0" >0.8836</td>
#       <td id="T_78990_row8_col1" class="data row8 col1" >0.5017</td>
#       <td id="T_78990_row8_col2" class="data row8 col2" >0.9754</td>
#       <td id="T_78990_row8_col3" class="data row8 col3" >0.9035</td>
#       <td id="T_78990_row8_col4" class="data row8 col4" >0.9381</td>
#       <td id="T_78990_row8_col5" class="data row8 col5" >-0.0027</td>
#       <td id="T_78990_row8_col6" class="data row8 col6" >-0.0035</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_78990_row9_col0" class="data row9 col0" >0.8838</td>
#       <td id="T_78990_row9_col1" class="data row9 col1" >0.5004</td>
#       <td id="T_78990_row9_col2" class="data row9 col2" >0.9760</td>
#       <td id="T_78990_row9_col3" class="data row9 col3" >0.9032</td>
#       <td id="T_78990_row9_col4" class="data row9 col4" >0.9382</td>
#       <td id="T_78990_row9_col5" class="data row9 col5" >-0.0074</td>
#       <td id="T_78990_row9_col6" class="data row9 col6" >-0.0096</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_78990_row10_col0" class="data row10 col0" >0.8844</td>
#       <td id="T_78990_row10_col1" class="data row10 col1" >0.4976</td>
#       <td id="T_78990_row10_col2" class="data row10 col2" >0.9762</td>
#       <td id="T_78990_row10_col3" class="data row10 col3" >0.9037</td>
#       <td id="T_78990_row10_col4" class="data row10 col4" >0.9385</td>
#       <td id="T_78990_row10_col5" class="data row10 col5" >-0.0005</td>
#       <td id="T_78990_row10_col6" class="data row10 col6" >-0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_78990_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_78990_row11_col0" class="data row11 col0" >0.0008</td>
#       <td id="T_78990_row11_col1" class="data row11 col1" >0.0061</td>
#       <td id="T_78990_row11_col2" class="data row11 col2" >0.0008</td>
#       <td id="T_78990_row11_col3" class="data row11 col3" >0.0003</td>
#       <td id="T_78
# CPU times: user 20min, sys: 1min 35s, total: 21min 35s
# Wall time: 45min 10s
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['page', 'race', 'class', 'ive',
#                                               'never', 'fan', 'girl', 'book',
#                                               'series', 'enjoyed', 'get', 'isnt',
#                                               'favorite', 'however',
#                                               'incredibly', 'awesom...
#                                                                  subsample_for_bin=200000,
#                                                                  subsample_freq=0))],
#                                      final_estimator=LogisticRegression(C=1.0,
#                                                                         class_weight=None,
#                                                                         dual=False,
#                                                                         fit_intercept=True,
#                                                                         intercept_scaling=1,
#                                                                         l1_ratio=None,
#                                                                         max_iter=1000,
#                                                                         multi_class='auto',
#                                                                         n_jobs=None,
#                                                                         penalty='l2',
#                                                                         random_state=5,
#                                                                         solver='lbfgs',
#                                                                         tol=0.0001,
#                                                                         verbose=0,
#                                                                         warm_start=False),
#                                      n_jobs=-1, passthrough=True,
#                                      stack_method='auto', verbose=0))],
#           verbose=False),
#  'stacker_et.pkl')

# %%
# %time blender_weighted_hard = blend_models(best_models, weights = [0.50,0.30,0.20], method='hard')
save_model(blender_weighted_hard , 'blender_weighted_hard')
# Out:
# <style type="text/css">
# #T_7464f_row10_col0, #T_7464f_row10_col1, #T_7464f_row10_col2, #T_7464f_row10_col3, #T_7464f_row10_col4, #T_7464f_row10_col5, #T_7464f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7464f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7464f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7464f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7464f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7464f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7464f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7464f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7464f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7464f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7464f_row0_col0" class="data row0 col0" >0.8686</td>
#       <td id="T_7464f_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_7464f_row0_col2" class="data row0 col2" >0.9561</td>
#       <td id="T_7464f_row0_col3" class="data row0 col3" >0.9040</td>
#       <td id="T_7464f_row0_col4" class="data row0 col4" >0.9293</td>
#       <td id="T_7464f_row0_col5" class="data row0 col5" >0.0040</td>
#       <td id="T_7464f_row0_col6" class="data row0 col6" >0.0043</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7464f_row1_col0" class="data row1 col0" >0.8702</td>
#       <td id="T_7464f_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_7464f_row1_col2" class="data row1 col2" >0.9583</td>
#       <td id="T_7464f_row1_col3" class="data row1 col3" >0.9039</td>
#       <td id="T_7464f_row1_col4" class="data row1 col4" >0.9303</td>
#       <td id="T_7464f_row1_col5" class="data row1 col5" >0.0030</td>
#       <td id="T_7464f_row1_col6" class="data row1 col6" >0.0033</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7464f_row2_col0" class="data row2 col0" >0.8647</td>
#       <td id="T_7464f_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_7464f_row2_col2" class="data row2 col2" >0.9523</td>
#       <td id="T_7464f_row2_col3" class="data row2 col3" >0.9033</td>
#       <td id="T_7464f_row2_col4" class="data row2 col4" >0.9271</td>
#       <td id="T_7464f_row2_col5" class="data row2 col5" >-0.0059</td>
#       <td id="T_7464f_row2_col6" class="data row2 col6" >-0.0063</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7464f_row3_col0" class="data row3 col0" >0.8715</td>
#       <td id="T_7464f_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_7464f_row3_col2" class="data row3 col2" >0.9589</td>
#       <td id="T_7464f_row3_col3" class="data row3 col3" >0.9046</td>
#       <td id="T_7464f_row3_col4" class="data row3 col4" >0.9310</td>
#       <td id="T_7464f_row3_col5" class="data row3 col5" >0.0133</td>
#       <td id="T_7464f_row3_col6" class="data row3 col6" >0.0146</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7464f_row4_col0" class="data row4 col0" >0.8656</td>
#       <td id="T_7464f_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_7464f_row4_col2" class="data row4 col2" >0.9526</td>
#       <td id="T_7464f_row4_col3" class="data row4 col3" >0.9039</td>
#       <td id="T_7464f_row4_col4" class="data row4 col4" >0.9276</td>
#       <td id="T_7464f_row4_col5" class="data row4 col5" >0.0020</td>
#       <td id="T_7464f_row4_col6" class="data row4 col6" >0.0022</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7464f_row5_col0" class="data row5 col0" >0.8664</td>
#       <td id="T_7464f_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_7464f_row5_col2" class="data row5 col2" >0.9542</td>
#       <td id="T_7464f_row5_col3" class="data row5 col3" >0.9034</td>
#       <td id="T_7464f_row5_col4" class="data row5 col4" >0.9281</td>
#       <td id="T_7464f_row5_col5" class="data row5 col5" >-0.0045</td>
#       <td id="T_7464f_row5_col6" class="data row5 col6" >-0.0049</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7464f_row6_col0" class="data row6 col0" >0.8677</td>
#       <td id="T_7464f_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_7464f_row6_col2" class="data row6 col2" >0.9552</td>
#       <td id="T_7464f_row6_col3" class="data row6 col3" >0.9039</td>
#       <td id="T_7464f_row6_col4" class="data row6 col4" >0.9288</td>
#       <td id="T_7464f_row6_col5" class="data row6 col5" >0.0027</td>
#       <td id="T_7464f_row6_col6" class="data row6 col6" >0.0030</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7464f_row7_col0" class="data row7 col0" >0.8666</td>
#       <td id="T_7464f_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_7464f_row7_col2" class="data row7 col2" >0.9540</td>
#       <td id="T_7464f_row7_col3" class="data row7 col3" >0.9037</td>
#       <td id="T_7464f_row7_col4" class="data row7 col4" >0.9282</td>
#       <td id="T_7464f_row7_col5" class="data row7 col5" >0.0006</td>
#       <td id="T_7464f_row7_col6" class="data row7 col6" >0.0007</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7464f_row8_col0" class="data row8 col0" >0.8655</td>
#       <td id="T_7464f_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_7464f_row8_col2" class="data row8 col2" >0.9533</td>
#       <td id="T_7464f_row8_col3" class="data row8 col3" >0.9032</td>
#       <td id="T_7464f_row8_col4" class="data row8 col4" >0.9276</td>
#       <td id="T_7464f_row8_col5" class="data row8 col5" >-0.0073</td>
#       <td id="T_7464f_row8_col6" class="data row8 col6" >-0.0078</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7464f_row9_col0" class="data row9 col0" >0.8658</td>
#       <td id="T_7464f_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_7464f_row9_col2" class="data row9 col2" >0.9536</td>
#       <td id="T_7464f_row9_col3" class="data row9 col3" >0.9033</td>
#       <td id="T_7464f_row9_col4" class="data row9 col4" >0.9278</td>
#       <td id="T_7464f_row9_col5" class="data row9 col5" >-0.0054</td>
#       <td id="T_7464f_row9_col6" class="data row9 col6" >-0.0058</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7464f_row10_col0" class="data row10 col0" >0.8672</td>
#       <td id="T_7464f_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_7464f_row10_col2" class="data row10 col2" >0.9548</td>
#       <td id="T_7464f_row10_col3" class="data row10 col3" >0.9037</td>
#       <td id="T_7464f_row10_col4" class="data row10 col4" >0.9286</td>
#       <td id="T_7464f_row10_col5" class="data row10 col5" >0.0003</td>
#       <td id="T_7464f_row10_col6" class="data row10 col6" >0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_7464f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7464f_row11_col0" class="data row11 col0" >0.0021</td>
#       <td id="T_7464f_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_7464f_row11_col2" class="data row11 col2" >0.0022</td>
#       <td id="T_7464f_row11_col3" class="data row11 col3" >0.0004</td>
#       <td id="T_7464f_ro
# CPU times: user 4min 54s, sys: 1min 33s, total: 6min 28s
# Wall time: 11min 48s
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['page', 'race', 'class', 'ive',
#                                               'never', 'fan', 'girl', 'book',
#                                               'series', 'enjoyed', 'get', 'isnt',
#                                               'favorite', 'however',
#                                               'incredibly', 'awesom...
#                                                                learning_rate=0.1,
#                                                                max_depth=-1,
#                                                                min_child_samples=20,
#                                                                min_child_weight=0.001,
#                                                                min_split_gain=0.0,
#                                                                n_estimators=100,
#                                                                n_jobs=-1,
#                                                                num_leaves=31,
#                                                                objective=None,
#                                                                random_state=5,
#                                                                reg_alpha=0.0,
#                                                                reg_lambda=0.0,
#                                                                silent='warn',
#                                                                subsample=1.0,
#                                                                subsample_for_bin=200000,
#                                                                subsample_freq=0))],
#                                    flatten_transform=True, n_jobs=-1,
#                                    verbose=False, voting='hard',
#                                    weights=[0.5, 0.3, 0.2]))],
#           verbose=False),
#  'blender_weighted_hard.pkl')
